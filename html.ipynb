# %% [markdown]
# Trabajo Final
#
#
#
# Para los indicadores de desarrollo global:
#
# puedes ver la evolución en el tiempo de un sólo indicador, para un sólo pais, o región.
# Puedes hacer la comparación entre la evolucion de varios países.
# puedes ver la comparación entre países de un sólo indicador. Puedes enfocarte en una o varias regiones.
# puedes ver la relación de dos o más indicadores.
#
# Realizar 2 gráficos hechos con código, para lo que se requiera limpieza de datos
# (data wrangling). Se podrá elegir entre un conjunto de bases de datos que
# pondré a disposición.
#
# - Pautas generales
# o Debe manejar al menos dataframes y listas.
# o Debe contener al menos una transformación respecto a la base de datos “cruda”.
# o Dicha transformación debe utilizar una función escrita por la/el estudiante, tal que modifique la base de datos.
# o Se puede trabajar en grupo de máximo 2 estudiantes. Si se opta por esta opción,
# se deberán incluir 3 gráficos.

# %%
PAQUETES NECESARIOS:

# %%
import pandas as pd
# !pip install altair
import altair as alt
alt.data_transformers.enable('vegafusion')

# !pip install wbgapi
import wbgapi as wb

# !pip install altair_saver

# %% [markdown]
# Bases de datos

# %%
#bd=pd.read_csv("C:/Users/Lorena/Documents/curso python/proyecto/proyecto_final2024/51f7ab6a-24ed-4a06-9f5d-04873f1673fd_Series - Metadata-2.csv",encoding='latin-1')
#bd
# Out:
#            Country Name                                       Country Code  \
# 0           Afghanistan                                                AFG
# 1           Afghanistan                                                AFG
# 2           Afghanistan                                                AFG
# 3           Afghanistan                                                AFG
# 4           Afghanistan                                                AFG
# ...                 ...                                                ...
# 1603  EG.ELC.ACCS.RU.ZS                                          CC BY-4.0
# 1604     EN.ATM.CO2E.PC  Attribution-NonCommercial 4.0 International (C...
# 1605  NY.GDP.MKTP.KD.ZG                                          CC BY-4.0
# 1606     SH.MED.BEDS.ZS                                          CC BY-4.0
# 1607  SL.TLF.TOTL.FE.ZS                                          CC BY-4.0
#
#                                             Series Name  \
# ...

# %%
bdnew=pd.read_csv("C:/Users/Lorena/Documents/curso python/proyecto/proyecto_final2024/51f7ab6a-24ed-4a06-9f5d-04873f1673fd_Data-1.csv",encoding='latin-1')
bdnew
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                          Afghanistan          AFG
# 2                                          Afghanistan          AFG
# 3                                          Afghanistan          AFG
# 4                                          Afghanistan          AFG
# ...                                                ...          ...
# 1596                                               NaN          NaN
# 1597                                               NaN          NaN
# 1598                                               NaN          NaN
# 1599  Data from database: World Development Indicators          NaN
# 1600                          Last Updated: 12/18/2023          NaN
#
#                                             Series Name        Series Code  \
# ...

# %%
bdnew.shape
# Out:
# (1601, 67)

# %%
#viendo nombre de variables
nombre_variables=bdnew.columns
print(nombre_variables)
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '
head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2             CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 3                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 4                   Hospital beds (per 1,000 people)     SH.MED.BEDS.ZS
#
#                 1960 1961 1962 1963 1964 1965  ...              2013  \
# 0                 ..   ..   ..   ..   ..   ..  ...  68.0408782958984
# 1                 ..   ..   ..   ..   ..   ..  ...  60.2391977225107
# 2                 ..   ..   ..   ..   ..   ..  ...  0.29808781267706
# 3                 ..   ..   ..   ..   ..   ..  ...  5.60074465808174
# ...

# %% [markdown]
# PARA TRABAJAR, BORRARE LOS VALORES FINALES DE ABAJO
#
# Usando bd2.tail, se puede ver que el último valor útil es World, a partir de allí vienen NaN, y códigos sin valores. Esos los eliminaré

# %%
#bd2.tail(20)

#ubicar la ultima observacion con info, osea World

ubi=bd2new.set_index('Country Name')
world_data_loc = bd2new.loc[bd2new['Country Name'] == 'World']
world_data_loc

#World acaba en observación #1595

#Eliminar lo ultimo

def elim_ultimo(bd2new,primera,final):
    bd2new.drop(bd2new.index[primera:final],inplace=True)
elim_ultimo(bd2new,1596,1608)
bd2new
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 1591        World          WLD
# 1592        World          WLD
# 1593        World          WLD
# 1594        World          WLD
# 1595        World          WLD
#
#                                             Series Name        Series Code  \
# 0               Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1     Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2                CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 3                                 GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 4                      Hospital beds (per 1,000 people)     SH.MED.BEDS.ZS
# ...                                                 ...                ...
# ...

# %%
CONVERTIR TODA LA BASE DE WIDE A LONG Y A WIDE PARA QUE LOS AÑOS SEAN 1 COLUMNA, Y LA SERIE SE DIVIDA EN COLUMNAS

# %%
bdtotal=pd.melt(bd2new, id_vars=['Country Name','Series Name'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
    '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
    '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
    '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
    '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'])

bdtotal

#Cambiando nombre de la variable año a Año
Año={'variable':'Año'}
bdtotal.rename(columns=Año,inplace=True)
bdtotal

#Convertir a numericas la columna 'value'
bdtotal['value'] = pd.to_numeric(bdtotal['value'], errors='coerce')
bdtotal['value'] = bdtotal['value'].astype(float)

#base de datos total ya en wide con las variables de series y año en columnas
bdtotal2=pd.pivot_table(bdtotal, columns='Series Name', index=['Country Name','Año'], values='value').reset_index()
bdtotal2
# Out:
# Series Name Country Name   Año  Access to electricity (% of population)  \
# 0            Afghanistan  1960                                      NaN
# 1            Afghanistan  1970                                      NaN
# 2            Afghanistan  1981                                      NaN
# 3            Afghanistan  1987                                      NaN
# 4            Afghanistan  1990                                      NaN
# ...                  ...   ...                                      ...
# 13848           Zimbabwe  2018                                45.400288
# 13849           Zimbabwe  2019                                46.682095
# 13850           Zimbabwe  2020                                52.747667
# 13851           Zimbabwe  2021                                48.979927
# 13852           Zimbabwe  2022                                      NaN
#
# Series Name  Access to electricity, rural (% of rural population)  \
# ...

# %% [raw]
# GRAFICOS

# %%
#Grafico de Perú -Electricidad de total de poblacion a lo largo de los años

perubd=bdtotal2[bdtotal2['Country Name']=='Peru']

alt.Chart(perubd).mark_point().encode(
    alt.X('Año'),
    alt.Y("Access to electricity (% of population)"),
    tooltip=["Access to electricity (% of population)", "Año"]
).interactive().properties(
    title={"text": "Porcentaje de acceso a electricidad en Perú 1960-2022", "color": "Black"}).configure_axisX(labelAngle=45)
# Out:
# alt.Chart(...)

# %%
latinbd=bdtotal2[bdtotal2['Country Name']=='Latin America & Caribbean']
americabd=bdtotal2[bdtotal2['Country Name']=='North America']
eastbd=bdtotal2[bdtotal2['Country Name']=='Middle East & North Africa']
eurobd=bdtotal2[bdtotal2['Country Name']=='European Union']
sudasia=bdtotal2[bdtotal2['Country Name']=='South Asia']
world=bdtotal2[bdtotal2['Country Name']=='World']

#América Latina

latin=alt.Chart(latinbd).mark_point().encode(
    alt.X('Año'),
    alt.Y("CO2 emissions (metric tons per capita)"),color="Country Name",
    tooltip=["CO2 emissions (metric tons per capita)", "Año"]
).interactive().properties( title={"text": "Emisiones de CO2 por región", "color": "Black"} )

#Norte América

america=alt.Chart(americabd).mark_point().encode(
    alt.X('Año'),
    alt.Y("CO2 emissions (metric tons per capita)"),color="Country Name",
    tooltip=["CO2 emissions (metric tons per capita)", "Año"]
).interactive()

# Oriente Medio y Africa del Norte
east=alt.Chart(eastbd).mark_point().encode(
    alt.X('Año'),
    alt.Y("CO2 emissions (metric tons per capita)"),color="Country Name",
    tooltip=["CO2 emissions (metric tons per capita)", "Año"]
).interactive()

#Europa

euro=alt.Chart(eurobd).mark_point().encode(
    alt.X('Año'),
    alt.Y("CO2 emissions (metric tons per capita)"),color="Country Name",
    tooltip=["CO2 emissions (metric tons per capita)", "Año"]
).interactive()

#Asia Sur

asiasur=alt.Chart(sudasia).mark_point().encode(
    alt.X('Año'),
    alt.Y("CO2 emissions (metric tons per capita)"),color="Country Name",
    tooltip=["CO2 emissions (metric tons per capita)", "Año"]
).interactive()

#Mundo

mundo=alt.Chart(world).mark_point().encode(
    alt.X('Año'),
    alt.Y("CO2 emissions (metric tons per capita)"),color="Country Name",
    tooltip=["CO2 emissions (metric tons per capita)", "Año"]
).interactive()

# %%
grande=latin+america+east+euro+asiasur+mundo
grande
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Adicional, solo con tabla con los países

# %%
#Eliminando a partir de Zimbabwe


ubi=bd2new.set_index('Country Name')
Zimbabwe_data_loc = bd2new.loc[bd2new['Country Name'] == 'Zimbabwe']
Zimbabwe_data_loc

#termina en 1301

#Eliminar lo ultimo

solo_paises=bd2new.copy()

def elim_ultimo(solo_paises,primera,final):
    solo_paises.drop(solo_paises.index[primera:final],inplace=True)
elim_ultimo(solo_paises,1302,1596)

#convertirlo a formato usable

solo_paises=pd.melt(bd2new, id_vars=['Country Name','Series Name'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
   '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
  '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
 '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
 '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'])


#Cambiando nombre de la variable año a Año
Año={'variable':'Año'}
solo_paises.rename(columns=Año,inplace=True)

#Convertir a numericas la columna 'value'
solo_paises['value'] = pd.to_numeric(solo_paises['value'], errors='coerce')
solo_paises['value'] = solo_paises['value'].astype(float)

#base de datos total ya en wide con las variables de series y año en columnas

solo_paises2=pd.pivot_table(solo_paises, columns='Series Name', index=['Country Name','Año'], values='value').reset_index()
solo_paises2.head()
# Out:
# Series Name Country Name   Año  Access to electricity (% of population)  \
# 0            Afghanistan  1960                                      NaN
# 1            Afghanistan  1970                                      NaN
# 2            Afghanistan  1981                                      NaN
# 3            Afghanistan  1987                                      NaN
# 4            Afghanistan  1990                                      NaN
#
# Series Name  Access to electricity, rural (% of rural population)  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4                                                          NaN
#
# Series Name  CO2 emissions (metric tons per capita)  GDP growth (annual %)  \
# ...

# %%
p1992=solo_paises2[solo_paises2['Año']=='1992']
p2002=solo_paises2[solo_paises2['Año']=='2002']
p2012=solo_paises2[solo_paises2['Año']=='2012']
p2022=solo_paises2[solo_paises2['Año']=='2022']


g1 = alt.Chart(p1992).mark_point().encode(x="Labor force, female (% of total labor force)",y= "GDP growth (annual %)",
                                          color='Country Name', 
                                          tooltip = ["Labor force, female (% of total labor force)","Country Name","GDP growth (annual %)"]).interactive().properties(
title="Porcentaje fuerza laboral femenina y crecimiento GDP por país-1992")


g2 = alt.Chart(p2002).mark_point().encode(x="Labor force, female (% of total labor force)",y= "GDP growth (annual %)",
                                          color='Country Name', 
                                          tooltip = ["Labor force, female (% of total labor force)","Country Name","GDP growth (annual %)"]).interactive().properties(
title="Porcentaje fuerza laboral femenina y crecimiento GDP por país-2002")


g3 = alt.Chart(p2012).mark_point().encode(x="Labor force, female (% of total labor force)",y= "GDP growth (annual %)",
                                          color='Country Name', 
                                          tooltip = ["Labor force, female (% of total labor force)","Country Name","GDP growth (annual %)"]).interactive().properties(
title="Porcentaje fuerza laboral femenina y crecimiento GDP por país-2012")

g4 = alt.Chart(p2022).mark_point().encode(x="Labor force, female (% of total labor force)",y= "GDP growth (annual %)",
                                          color='Country Name', 
                                          tooltip = ["Labor force, female (% of total labor force)","Country Name","GDP growth (annual %)"]).interactive().properties(
title="Porcentaje fuerza laboral femenina y crecimiento GDP por país-2022")


alt.vconcat(alt.hconcat(g1,g2),alt.hconcat(g3,g4))
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# Fin.
